# %%
import os
import pandas as pd

def load_accent_info(accent_file):
    """
    アクセント情報を読み込む関数。
    """
    with open(accent_file, "r") as f:
        accent_lines = f.readlines()
    accent_info = [list(map(int, line.strip().split(","))) for line in accent_lines]
    return accent_info

def combine_features_with_accent(features_dir, accent_info, output_dir):
    """
    音素と特徴量にアクセント情報を組み合わせて保存する関数。
    """
    # 入力ディレクトリのCSVファイルを取得
    feature_files = sorted([f for f in os.listdir(features_dir) if f.endswith(".csv")])
    
    os.makedirs(output_dir, exist_ok=True)  # 出力ディレクトリを作成

    for idx, feature_file in enumerate(feature_files):
        feature_path = os.path.join(features_dir, feature_file)
        output_path = os.path.join(output_dir, feature_file)
        
        if idx >= len(accent_info):
            print(f"Warning: Accent information is missing for {feature_file}. Skipping.")
            continue

        # 特徴量ファイルを読み込む
        features_df = pd.read_csv(feature_path)
        
        # アクセント情報を取得
        accents = accent_info[idx]
        
        # 音素数とアクセント数が一致しない場合のチェック
        if len(features_df) != len(accents):
            print(f"Error: Mismatch in length for {feature_file}. Features: {len(features_df)}, Accents: {len(accents)}")
            continue

        # アクセント情報を結合
        features_df["Accent"] = accents

        # 出力ファイルとして保存
        features_df.to_csv(output_path, index=False)
        print(f"Saved combined features with accent to {output_path}")

# メイン処理
if __name__ == "__main__":
    features_directory = "./basic5000_HuBERT_features_csv"  # 音素と特徴量が保存されたディレクトリ
    accent_file_path = "./jsut_accent_onsoretu/onsoretu_re_re_split.csv"  # アクセント情報ファイル
    output_directory = "./basic5000_features_with_accent"  # 出力先ディレクトリ

    # アクセント情報を読み込み
    accent_information = load_accent_info(accent_file_path)

    # 音素と特徴量にアクセントを結合
    combine_features_with_accent(features_directory, accent_information, output_directory)
# Out:
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0001.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0002.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0003.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0004.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0005.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0006.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0007.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0008.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0009.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0010.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0011.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0012.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0013.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0014.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0015.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0016.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0017.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0018.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0019.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0020.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0021.csv
# Error: Mismatch in length for alignment_0022.csv. Features: 21, Accents: 22
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0023.csv
# Error: Mismatch in length for alignment_0024.csv. Features: 61, Accents: 60
# Error: Mismatch in length for alignment_0025.csv. Features: 22, Accents: 23
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0026.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0027.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0028.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0029.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0030.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0031.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0032.csv
# Error: Mismatch in length for alignment_0033.csv. Features: 20, Accents: 21
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0034.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0035.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0036.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0037.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0038.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0039.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0040.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0041.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0042.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0043.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0044.csv
# Error: Mismatch in length for alignment_0045.csv. Features: 19, Accents: 20
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0046.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0047.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0048.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0049.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0050.csv
# Error: Mismatch in length for alignment_0051.csv. Features: 26, Accents: 27
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0052.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0053.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0054.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0055.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0056.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0057.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0058.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0059.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0060.csv
# Error: Mismatch in length for alignment_0061.csv. Features: 21, Accents: 22
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0062.csv
# Error: Mismatch in length for alignment_0063.csv. Features: 16, Accents: 17
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0064.csv
# Error: Mismatch in length for alignment_0065.csv. Features: 39, Accents: 40
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0066.csv
# Error: Mismatch in length for alignment_0067.csv. Features: 34, Accents: 33
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0068.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0069.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0070.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0071.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0072.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0073.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0074.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0075.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0076.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0077.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0078.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0079.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0080.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0081.csv
# Error: Mismatch in length for alignment_0082.csv. Features: 19, Accents: 20
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0083.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0500.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0501.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0502.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0503.csv
# Error: Mismatch in length for alignment_0504.csv. Features: 25, Accents: 26
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0505.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0506.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0507.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0508.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0509.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0510.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0511.csv
# Error: Mismatch in length for alignment_0512.csv. Features: 17, Accents: 18
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0513.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0514.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0515.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0516.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0517.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0518.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0519.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0520.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0521.csv
# Error: Mismatch in length for alignment_0522.csv. Features: 18, Accents: 19
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0523.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0524.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0525.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0526.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0527.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0528.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0529.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0530.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0531.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0532.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0533.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0534.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0535.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0536.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0537.csv
# ...
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4825.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4826.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4827.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4828.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4829.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4830.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4831.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4832.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4833.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4834.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4835.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4836.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4837.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4838.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4839.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4840.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4841.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4842.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4843.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4844.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4845.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4846.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4847.csv
# Error: Mismatch in length for alignment_4848.csv. Features: 24, Accents: 25
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4849.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4850.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4851.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4852.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4853.csv
# Error: Mismatch in length for alignment_4854.csv. Features: 9, Accents: 10
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4855.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4856.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4857.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4858.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4859.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4860.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4861.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4862.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4863.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4864.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4865.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4866.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4867.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4868.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4869.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4870.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4871.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4872.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4873.csv
# Error: Mismatch in length for alignment_4874.csv. Features: 10, Accents: 11
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4875.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4876.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4877.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4878.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4879.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4880.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4881.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4882.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4883.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4884.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4885.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4886.csv
# Error: Mismatch in length for alignment_4887.csv. Features: 31, Accents: 32
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4888.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4889.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4890.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4891.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4892.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4893.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4894.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4895.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4896.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4897.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4898.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4899.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4900.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4901.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4902.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4903.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4904.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4905.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4906.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4907.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4908.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4909.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4910.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4911.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4912.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4913.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4914.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4915.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4916.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4917.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4918.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4919.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4920.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4921.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4922.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4923.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4924.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4925.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4926.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4927.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4928.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4929.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4930.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4931.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4932.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4933.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4934.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4935.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4936.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4937.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4938.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4939.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4940.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4941.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4942.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4943.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4944.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4945.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4946.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4947.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4948.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4949.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4950.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4951.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4952.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4953.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4954.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4955.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4956.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4957.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4958.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4959.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4960.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4961.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4962.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4963.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4964.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4965.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4966.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4967.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4968.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4969.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4970.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4971.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4972.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4973.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4974.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4975.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4976.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4977.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4978.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4979.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4980.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4981.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4982.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4983.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4984.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4985.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4986.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4987.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4988.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4989.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4990.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4991.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4992.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4993.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4994.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4995.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4996.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4997.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4998.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4999.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_5000.csv

# %%
# エラーを別ファイルとして保存（デバッグ用）
import os
import pandas as pd

def load_accent_info(accent_file):
    """
    アクセント情報を読み込む関数。
    """
    with open(accent_file, "r") as f:
        accent_lines = f.readlines()
    accent_info = [list(map(int, line.strip().split(","))) for line in accent_lines]
    return accent_info

def log_error(error_message, error_file_name):
    """
    エラーメッセージとファイル名をエラーログに保存する関数。
    """
    error_dir = "error_logs"
    os.makedirs(error_dir, exist_ok=True)  # エラーログディレクトリを作成

    error_log_path = os.path.join(error_dir, error_file_name.replace('.csv', '_error.txt'))
    with open(error_log_path, "w") as f:
        f.write(error_message)

def combine_features_with_accent(features_dir, accent_info, output_dir):
    """
    音素と特徴量にアクセント情報を組み合わせて保存する関数。
    """
    # 入力ディレクトリのCSVファイルを取得
    feature_files = sorted([f for f in os.listdir(features_dir) if f.endswith(".csv")])
    
    os.makedirs(output_dir, exist_ok=True)  # 出力ディレクトリを作成

    for idx, feature_file in enumerate(feature_files):
        feature_path = os.path.join(features_dir, feature_file)
        output_path = os.path.join(output_dir, feature_file)
        
        if idx >= len(accent_info):
            print(f"Warning: Accent information is missing for {feature_file}. Skipping.")
            continue

        # 特徴量ファイルを読み込む
        features_df = pd.read_csv(feature_path)
        
        # アクセント情報を取得
        accents = accent_info[idx]
        
        # 音素数とアクセント数が一致しない場合のチェック
        if len(features_df) != len(accents):
            error_message = f"Error: Mismatch in length for {feature_file}. Features: {len(features_df)}, Accents: {len(accents)}"
            print(error_message)
            log_error(error_message, feature_file)  # エラーログを保存
            continue

        # アクセント情報を結合
        features_df["Accent"] = accents

        # 出力ファイルとして保存
        features_df.to_csv(output_path, index=False)
        print(f"Saved combined features with accent to {output_path}")

# メイン処理
if __name__ == "__main__":
    features_directory = "./basic5000_HuBERT_features_csv"  # 音素と特徴量が保存されたディレクトリ
    accent_file_path = "./jsut_accent_onsoretu/onsoretu_re_re_fi_split.csv"  # アクセント情報ファイル,フィは１文字
    output_directory = "./basic5000_features_with_accent"  # 出力先ディレクトリ

    # アクセント情報を読み込み
    accent_information = load_accent_info(accent_file_path)

    # 音素と特徴量にアクセントを結合
    combine_features_with_accent(features_directory, accent_information, output_directory)
# Out:
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0001.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0002.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0003.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0004.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0005.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0006.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0007.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0008.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0009.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0010.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0011.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0012.csv
# Error: Mismatch in length for alignment_0013.csv. Features: 30, Accents: 31
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0014.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0015.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0016.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0017.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0018.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0019.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0020.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0021.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0022.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0023.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0024.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0025.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0026.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0027.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0028.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0029.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0030.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0031.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0032.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0033.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0034.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0035.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0036.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0037.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0038.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0039.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0040.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0041.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0042.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0043.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0044.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0045.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0046.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0047.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0048.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0049.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0050.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0051.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0052.csv
# Error: Mismatch in length for alignment_0053.csv. Features: 25, Accents: 26
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0054.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0055.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0056.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0057.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0058.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0059.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0060.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0061.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0062.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0063.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0064.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0065.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0066.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0067.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0068.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0069.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0070.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0071.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0072.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0073.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0074.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0075.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0076.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0077.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0078.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0079.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0080.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0081.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0082.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0083.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0084.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0085.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0086.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0087.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0088.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0089.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0090.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0091.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0092.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0093.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0094.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0095.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0096.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0097.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0098.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0099.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0100.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0101.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0102.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0103.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0104.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0105.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0106.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0107.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0108.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0109.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0110.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0111.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0112.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0113.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0114.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0115.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0116.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0117.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0118.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0119.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0120.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0121.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0122.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0123.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0124.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0125.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0126.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0127.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0128.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0129.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0130.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0131.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0132.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0133.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0134.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0135.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0136.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0137.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0138.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0139.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0140.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0141.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0142.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0143.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0144.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0145.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0146.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0147.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0148.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0149.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0150.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0151.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0152.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0153.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0154.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0155.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0156.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0157.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0158.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0159.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0160.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0161.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0162.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0163.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0164.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0165.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0166.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0167.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0168.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0169.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0170.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0171.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0172.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0173.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0174.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0175.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0176.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0177.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0178.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0179.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0180.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0181.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0182.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0183.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0184.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0185.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0186.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0187.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0188.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0189.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0190.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0191.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0192.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0193.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0194.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0195.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0196.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0197.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0198.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0199.csv
# Error: Mismatch in length for alignment_0200.csv. Features: 19, Accents: 20
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0201.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0202.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0203.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0204.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0205.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0206.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0207.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0208.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0209.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0210.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_0211.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_
csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4875.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4876.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4877.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4878.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4879.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4880.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4881.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4882.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4883.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4884.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4885.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4886.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4887.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4888.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4889.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4890.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4891.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4892.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4893.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4894.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4895.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4896.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4897.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4898.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4899.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4900.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4901.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4902.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4903.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4904.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4905.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4906.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4907.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4908.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4909.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4910.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4911.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4912.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4913.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4914.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4915.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4916.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4917.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4918.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4919.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4920.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4921.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4922.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4923.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4924.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4925.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4926.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4927.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4928.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4929.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4930.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4931.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4932.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4933.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4934.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4935.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4936.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4937.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4938.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4939.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4940.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4941.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4942.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4943.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4944.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4945.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4946.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4947.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4948.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4949.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4950.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4951.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4952.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4953.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4954.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4955.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4956.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4957.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4958.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4959.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4960.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4961.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4962.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4963.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4964.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4965.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4966.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4967.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4968.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4969.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4970.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4971.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4972.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4973.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4974.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4975.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4976.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4977.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4978.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4979.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4980.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4981.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4982.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4983.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4984.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4985.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4986.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4987.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4988.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4989.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4990.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4991.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4992.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4993.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4994.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4995.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4996.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4997.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4998.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_4999.csv
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_5000.csv

# %%
import os
import pandas as pd

def load_accent_info(accent_file):
    """
    アクセント情報を読み込む関数。
    """
    with open(accent_file, "r") as f:
        accent_lines = f.readlines()
    accent_info = [list(map(int, line.strip().split(","))) for line in accent_lines]
    return accent_info

def log_error(error_message, error_file_name):
    """
    エラーメッセージとファイル名をエラーログに保存する関数。
    """
    error_dir = "error_logs"
    os.makedirs(error_dir, exist_ok=True)  # エラーログディレクトリを作成

    error_log_path = os.path.join(error_dir, error_file_name.replace('.csv', '_error.txt'))
    with open(error_log_path, "w") as f:
        f.write(error_message)

def combine_features_with_accent(features_dir, accent_info, output_dir):
    """
    音素と特徴量にアクセント情報を組み合わせて保存する関数。
    """
    # 入力ディレクトリのCSVファイルを取得
    feature_files = sorted([f for f in os.listdir(features_dir) if f.endswith(".csv")])
    
    os.makedirs(output_dir, exist_ok=True)  # 出力ディレクトリを作成

    error_count = 0  # エラーのカウントを初期化

    for idx, feature_file in enumerate(feature_files):
        feature_path = os.path.join(features_dir, feature_file)
        output_path = os.path.join(output_dir, feature_file)
        
        if idx >= len(accent_info):
            print(f"Warning: Accent information is missing for {feature_file}. Skipping.")
            continue

        # 特徴量ファイルを読み込む
        features_df = pd.read_csv(feature_path)
        
        # アクセント情報を取得
        accents = accent_info[idx]
        
        # 音素数とアクセント数が一致しない場合のチェック
        if len(features_df) != len(accents):
            error_message = f"Error: Mismatch in length for {feature_file}. Features: {len(features_df)}, Accents: {len(accents)}"
            print(error_message)
            log_error(error_message, feature_file)  # エラーログを保存
            error_count += 1  # エラーをカウント
            continue

        # アクセント情報を結合
        features_df["Accent"] = accents

        # 出力ファイルとして保存
        features_df.to_csv(output_path, index=False)
        print(f"Saved combined features with accent to {output_path}")

    # 最終的なエラーの総数を出力
    print(f"Total errors: {error_count}")

# メイン処理
if __name__ == "__main__":
    features_directory = "./basic5000_HuBERT_features_csv"  # 音素と特徴量が保存されたディレクトリ
    accent_file_path = "./jsut_accent_onsoretu/onsoretu_re_re_fi_split.csv"  # アクセント情報ファイル,フィは１文字
    output_directory = "./basic5000_features_with_accent"  # 出力先ディレクトリ

    # アクセント情報を読み込み
    accent_information = load_accent_info(accent_file_path)

    # 音素と特徴量にアクセントを結合
    combine_features_with_accent(features_directory, accent_information, output_directory)
# Out:
# Saved combined features with accent to ./basic5000_features_with_accent/alignment_