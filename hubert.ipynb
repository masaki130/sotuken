# %%
# HuBERTで特徴量を抽出(768次元らしい)
import torchaudio
import torchaudio.models
import torchaudio.transforms as transforms
import torch
import os
import numpy as np
import pandas as pd

# HuBERTモデルをロードする関数
def load_hubert_model():
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = torchaudio.models.hubert_base()
    model = model.to(device).eval()
    return model, device

# 音声ファイルからHuBERT特徴量を抽出する関数
def extract_hubert_features(audio_path, model, device):
    waveform, sample_rate = torchaudio.load(audio_path)
    if sample_rate != 16000:  # サンプリングレートを16kHzに変換
        resampler = transforms.Resample(orig_freq=sample_rate, new_freq=16000)
        waveform = resampler(waveform)
    waveform = waveform.to(device)
    with torch.no_grad():
        features, _ = model(waveform)
    return features.squeeze(0).cpu().numpy()  # 特徴量をNumPy配列として返す

# アライメント情報を使用して音節ごとの特徴量を抽出する関数
def extract_features_by_alignment(features, alignment_path, sample_rate=16000, hop_length=320):
    alignment = pd.read_csv(alignment_path)
    extracted_features = []
    for _, row in alignment.iterrows():
        start_frame = int(row['Start (s)'] * sample_rate // hop_length)
        end_frame = int(row['End (s)'] * sample_rate // hop_length)
        mora_features = features[start_frame:end_frame].mean(axis=0)  # 平均を計算
        extracted_features.append({
            "Mora": row['Mora'],
            **{f"Feature_{i}": value for i, value in enumerate(mora_features)}
        })
    return extracted_features

# 音声ファイルとアライメント情報を組み合わせて処理する関数
def process_audio_and_alignment(input_audio_dir, alignment_dir, output_dir, model, device, num_files=None):
    audio_files = sorted([f for f in os.listdir(input_audio_dir) if f.endswith(".wav")])
    if num_files is not None:
        audio_files = audio_files[:num_files]
    os.makedirs(output_dir, exist_ok=True)

    for audio_file in audio_files:
        audio_path = os.path.join(input_audio_dir, audio_file)
        alignment_file = f"alignment_{audio_file.replace('BASIC5000_', '').replace('.wav', '.csv')}"
        alignment_path = os.path.join(alignment_dir, alignment_file)
        output_path = os.path.join(output_dir, alignment_file)

        if not os.path.exists(alignment_path):
            print(f"Alignment file not found: {alignment_path}")
            continue

        print(f"Processing {audio_path} with {alignment_path}...")

        # HuBERT特徴量を抽出
        features = extract_hubert_features(audio_path, model, device)

        # 音節ごとの特徴量を抽出
        extracted_features = extract_features_by_alignment(features, alignment_path)

        # CSV形式で保存
        pd.DataFrame(extracted_features).to_csv(output_path, index=False)
        print(f"Saved features to {output_path}")

# メイン処理
if __name__ == "__main__":
    input_audio_directory = "./basic5000"  # 音声ファイルのディレクトリ
    alignment_directory = "./align_result_5000"  # アライメント情報のディレクトリ
    output_directory = "./basic5000_HuBERT_features_csv"  # 特徴量を保存するディレクトリ
    num_files_to_process = 5000  # 任意の処理ファイル数（例: 上から100個）

    # HuBERTモデルのロード
    hubert_model, device = load_hubert_model()

    # 音声とアライメント情報を組み合わせて処理
    process_audio_and_alignment(
        input_audio_directory,
        alignment_directory,
        output_directory,
        hubert_model,
        device,
        num_files=num_files_to_process
    )
# Out:
# Processing ./basic5000/BASIC5000_0001.wav with ./align_result_5000/alignment_0001.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0001.csv
# Processing ./basic5000/BASIC5000_0002.wav with ./align_result_5000/alignment_0002.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0002.csv
# Processing ./basic5000/BASIC5000_0003.wav with ./align_result_5000/alignment_0003.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0003.csv
# Processing ./basic5000/BASIC5000_0004.wav with ./align_result_5000/alignment_0004.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0004.csv
# Processing ./basic5000/BASIC5000_0005.wav with ./align_result_5000/alignment_0005.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0005.csv
# Processing ./basic5000/BASIC5000_0006.wav with ./align_result_5000/alignment_0006.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0006.csv
# Processing ./basic5000/BASIC5000_0007.wav with ./align_result_5000/alignment_0007.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0007.csv
# Processing ./basic5000/BASIC5000_0008.wav with ./align_result_5000/alignment_0008.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0008.csv
# Processing ./basic5000/BASIC5000_0009.wav with ./align_result_5000/alignment_0009.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0009.csv
# Processing ./basic5000/BASIC5000_0010.wav with ./align_result_5000/alignment_0010.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0010.csv
# Processing ./basic5000/BASIC5000_0011.wav with ./align_result_5000/alignment_0011.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0011.csv
# Processing ./basic5000/BASIC5000_0012.wav with ./align_result_5000/alignment_0012.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0012.csv
# Processing ./basic5000/BASIC5000_0013.wav with ./align_result_5000/alignment_0013.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0013.csv
# Processing ./basic5000/BASIC5000_0014.wav with ./align_result_5000/alignment_0014.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0014.csv
# Processing ./basic5000/BASIC5000_0015.wav with ./align_result_5000/alignment_0015.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0015.csv
# Processing ./basic5000/BASIC5000_0016.wav with ./align_result_5000/alignment_0016.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0016.csv
# Processing ./basic5000/BASIC5000_0017.wav with ./align_result_5000/alignment_0017.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0017.csv
# Processing ./basic5000/BASIC5000_0018.wav with ./align_result_5000/alignment_0018.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0018.csv
# Processing ./basic5000/BASIC5000_0019.wav with ./align_result_5000/alignment_0019.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0019.csv
# Processing ./basic5000/BASIC5000_0020.wav with ./align_result_5000/alignment_0020.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0020.csv
# Processing ./basic5000/BASIC5000_0021.wav with ./align_result_5000/alignment_0021.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0021.csv
# Processing ./basic5000/BASIC5000_0022.wav with ./align_result_5000/alignment_0022.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0022.csv
# Processing ./basic5000/BASIC5000_0023.wav with ./align_result_5000/alignment_0023.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0023.csv
# Processing ./basic5000/BASIC5000_0024.wav with ./align_result_5000/alignment_0024.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0024.csv
# Processing ./basic5000/BASIC5000_0025.wav with ./align_result_5000/alignment_0025.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0025.csv
# Processing ./basic5000/BASIC5000_0026.wav with ./align_result_5000/alignment_0026.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0026.csv
# Processing ./basic5000/BASIC5000_0027.wav with ./align_result_5000/alignment_0027.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0027.csv
# Processing ./basic5000/BASIC5000_0028.wav with ./align_result_5000/alignment_0028.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0028.csv
# Processing ./basic5000/BASIC5000_0029.wav with ./align_result_5000/alignment_0029.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0029.csv
# Processing ./basic5000/BASIC5000_0030.wav with ./align_result_5000/alignment_0030.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0030.csv
# Processing ./basic5000/BASIC5000_0031.wav with ./align_result_5000/alignment_0031.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0031.csv
# Processing ./basic5000/BASIC5000_0032.wav with ./align_result_5000/alignment_0032.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0032.csv
# Processing ./basic5000/BASIC5000_0033.wav with ./align_result_5000/alignment_0033.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0033.csv
# Processing ./basic5000/BASIC5000_0034.wav with ./align_result_5000/alignment_0034.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0034.csv
# Processing ./basic5000/BASIC5000_0035.wav with ./align_result_5000/alignment_0035.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0035.csv
# Processing ./basic5000/BASIC5000_0036.wav with ./align_result_5000/alignment_0036.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0036.csv
# Processing ./basic5000/BASIC5000_0037.wav with ./align_result_5000/alignment_0037.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0037.csv
# Processing ./basic5000/BASIC5000_0038.wav with ./align_result_5000/alignment_0038.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0038.csv
# Processing ./basic5000/BASIC5000_0039.wav with ./align_result_5000/alignment_0039.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0039.csv
# Processing ./basic5000/BASIC5000_0040.wav with ./align_result_5000/alignment_0040.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0040.csv
# Processing ./basic5000/BASIC5000_0041.wav with ./align_result_5000/alignment_0041.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0041.csv
# Processing ./basic5000/BASIC5000_0042.wav with ./align_result_5000/alignment_0042.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0042.csv
# Processing ./basic5000/BASIC5000_0043.wav with ./align_result_5000/alignment_0043.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0043.csv
# Processing ./basic5000/BASIC5000_0044.wav with ./align_result_5000/alignment_0044.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0044.csv
# Processing ./basic5000/BASIC5000_0045.wav with ./align_result_5000/alignment_0045.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0045.csv
# Processing ./basic5000/BASIC5000_0046.wav with ./align_result_5000/alignment_0046.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0046.csv
# Processing ./basic5000/BASIC5000_0047.wav with ./align_result_5000/alignment_0047.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0047.csv
# Processing ./basic5000/BASIC5000_0048.wav with ./align_result_5000/alignment_0048.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0048.csv
# Processing ./basic5000/BASIC5000_0049.wav with ./align_result_5000/alignment_0049.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0049.csv
# Processing ./basic5000/BASIC5000_0050.wav with ./align_result_5000/alignment_0050.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0050.csv
# Processing ./basic5000/BASIC5000_0051.wav with ./align_result_5000/alignment_0051.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0051.csv
# Processing ./basic5000/BASIC5000_0052.wav with ./align_result_5000/alignment_0052.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0052.csv
# Processing ./basic5000/BASIC5000_0053.wav with ./align_result_5000/alignment_0053.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0053.csv
# Processing ./basic5000/BASIC5000_0054.wav with ./align_result_5000/alignment_0054.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0054.csv
# Processing ./basic5000/BASIC5000_0055.wav with ./align_result_5000/alignment_0055.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0055.csv
# Processing ./basic5000/BASIC5000_0056.wav with ./align_result_5000/alignment_0056.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0056.csv
# Processing ./basic5000/BASIC5000_0057.wav with ./align_result_5000/alignment_0057.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0057.csv
# Processing ./basic5000/BASIC5000_0058.wav with ./align_result_5000/alignment_0058.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0058.csv
# Processing ./basic5000/BASIC5000_0059.wav with ./align_result_5000/alignment_0059.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0059.csv
# Processing ./basic5000/BASIC5000_0060.wav with ./align_result_5000/alignment_0060.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0060.csv
# Processing ./basic5000/BASIC5000_0061.wav with ./align_result_5000/alignment_0061.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0061.csv
# Processing ./basic5000/BASIC5000_0062.wav with ./align_result_5000/alignment_0062.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0062.csv
# Processing ./basic5000/BASIC5000_0063.wav with ./align_result_5000/alignment_0063.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0063.csv
# Processing ./basic5000/BASIC5000_0064.wav with ./align_result_5000/alignment_0064.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0064.csv
# Processing ./basic5000/BASIC5000_0065.wav with ./align_result_5000/alignment_0065.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0065.csv
# Processing ./basic5000/BASIC5000_0066.wav with ./align_result_5000/alignment_0066.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0066.csv
# Processing ./basic5000/BASIC5000_0067.wav with ./align_result_5000/alignment_0067.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0067.csv
# Processing ./basic5000/BASIC5000_0068.wav with ./align_result_5000/alignment_0068.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0068.csv
# Processing ./basic5000/BASIC5000_0069.wav with ./align_result_5000/alignment_0069.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0069.csv
# Processing ./basic5000/BASIC5000_0070.wav with ./align_result_5000/alignment_0070.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0070.csv
# Processing ./basic5000/BASIC5000_0071.wav with ./align_result_5000/alignment_0071.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0071.csv
# Processing ./basic5000/BASIC5000_0072.wav with ./align_result_5000/alignment_0072.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0072.csv
# Processing ./basic5000/BASIC5000_0073.wav with ./align_result_5000/alignment_0073.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0073.csv
# Processing ./basic5000/BASIC5000_0074.wav with ./align_result_5000/alignment_0074.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0074.csv
# Processing ./basic5000/BASIC5000_0075.wav with ./align_result_5000/alignment_0075.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0075.csv
# Processing ./basic5000/BASIC5000_0076.wav with ./align_result_5000/alignment_0076.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0076.csv
# Processing ./basic5000/BASIC5000_0077.wav with ./align_result_5000/alignment_0077.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0077.csv
# Processing ./basic5000/BASIC5000_0078.wav with ./align_result_5000/alignment_0078.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0078.csv
# Processing ./basic5000/BASIC5000_0079.wav with ./align_result_5000/alignment_0079.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0079.csv
# Processing ./basic5000/BASIC5000_0080.wav with ./align_result_5000/alignment_0080.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0080.csv
# Processing ./basic5000/BASIC5000_0081.wav with ./align_result_5000/alignment_0081.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0081.csv
# Processing ./basic5000/BASIC5000_0082.wav with ./align_result_5000/alignment_0082.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0082.csv
# Processing ./basic5000/BASIC5000_0083.wav with ./align_result_5000/alignment_0083.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0083.csv
# Processing ./basic5000/BASIC5000_0084.wav with ./align_result_5000/alignment_0084.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0084.csv
# Processing ./basic5000/BASIC5000_0085.wav with ./align_result_5000/alignment_0085.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0085.csv
# Processing ./basic5000/BASIC5000_0086.wav with ./align_result_5000/alignment_0086.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0086.csv
# Processing ./basic5000/BASIC5000_0087.wav with ./align_result_5000/alignment_0087.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0087.csv
# Processing ./basic5000/BASIC5000_0088.wav with ./align_result_5000/alignment_0088.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0088.csv
# Processing ./basic5000/BASIC5000_0089.wav with ./align_result_5000/alignment_0089.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0089.csv
# Processing ./basic5000/BASIC5000_0090.wav with ./align_result_5000/alignment_0090.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0090.csv
# Processing ./basic5000/BASIC5000_0091.wav with ./align_result_5000/alignment_0091.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0091.csv
# Processing ./basic5000/BASIC5000_0092.wav with ./align_result_5000/alignment_0092.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0092.csv
# Processing ./basic5000/BASIC5000_0093.wav with ./align_result_5000/alignment_0093.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0093.csv
# Processing ./basic5000/BASIC5000_0094.wav with ./align_result_5000/alignment_0094.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0094.csv
# Processing ./basic5000/BASIC5000_0095.wav with ./align_result_5000/alignment_0095.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0095.csv
# Processing ./basic5000/BASIC5000_0096.wav with ./align_result_5000/alignment_0096.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0096.csv
# Processing ./basic5000/BASIC5000_0097.wav with ./align_result_5000/alignment_0097.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0097.csv
# Processing ./basic5000/BASIC5000_0098.wav with ./align_result_5000/alignment_0098.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0098.csv
# Processing ./basic5000/BASIC5000_0099.wav with ./align_result_5000/alignment_0099.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0099.csv
# Processing ./basic5000/BASIC5000_0100.wav with ./align_result_5000/alignment_0100.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0100.csv
# Processing ./basic5000/BASIC5000_0101.wav with ./align_result_5000/alignment_0101.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0101.csv
# Processing ./basic5000/BASIC5000_0102.wav with ./align_result_5000/alignment_0102.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0102.csv
# Processing ./basic5000/BASIC5000_0103.wav with ./align_result_5000/alignment_0103.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0103.csv
# Processing ./basic5000/BASIC5000_0104.wav with ./align_result_5000/alignment_0104.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0104.csv
# Processing ./basic5000/BASIC5000_0105.wav with ./align_result_5000/alignment_0105.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0105.csv
# Processing ./basic5000/BASIC5000_0106.wav with ./align_result_5000/alignment_0106.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0106.csv
# Processing ./basic5000/BASIC5000_0107.wav with ./align_result_5000/alignment_0107.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0107.csv
# Processing ./basic5000/BASIC5000_0108.wav with ./align_result_5000/alignment_0108.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0108.csv
# Processing ./basic5000/BASIC5000_0109.wav with ./align_result_5000/alignment_0109.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0109.csv
# Processing ./basic5000/BASIC5000_0110.wav with ./align_result_5000/alignment_0110.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0110.csv
# Processing ./basic5000/BASIC5000_0111.wav with ./align_result_5000/alignment_0111.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0111.csv
# Processing ./basic5000/BASIC5000_0112.wav with ./align_result_5000/alignment_0112.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0112.csv
# Processing ./basic5000/BASIC5000_0113.wav with ./align_result_5000/alignment_0113.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0113.csv
# Processing ./basic5000/BASIC5000_0114.wav with ./align_result_5000/alignment_0114.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0114.csv
# Processing ./basic5000/BASIC5000_0115.wav with ./align_result_5000/alignment_0115.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0115.csv
# Processing ./basic5000/BASIC5000_0116.wav with ./align_result_5000/alignment_0116.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0116.csv
# Processing ./basic5000/BASIC5000_0117.wav with ./align_result_5000/alignment_0117.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0117.csv
# Processing ./basic5000/BASIC5000_0118.wav with ./align_result_5000/alignment_0118.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0118.csv
# Processing ./basic5000/BASIC5000_0119.wav with ./align_result_5000/alignment_0119.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0119.csv
# Processing ./basic5000/BASIC5000_0120.wav with ./align_result_5000/alignment_0120.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0120.csv
# Processing ./basic5000/BASIC5000_0121.wav with ./align_result_5000/alignment_0121.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0121.csv
# Processing ./basic5000/BASIC5000_0122.wav with ./align_result_5000/alignment_0122.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0122.csv
# Processing ./basic5000/BASIC5000_0123.wav with ./align_result_5000/alignment_0123.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0123.csv
# Processing ./basic5000/BASIC5000_0124.wav with ./align_result_5000/alignment_0124.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0124.csv
# Processing ./basic5000/BASIC5000_0125.wav with ./align_result_5000/alignment_0125.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0125.csv
# Processing ./basic5000/BASIC5000_0126.wav with ./align_result_5000/alignment_0126.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0126.csv
# Processing ./basic5000/BASIC5000_0127.wav with ./align_result_5000/alignment_0127.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0127.csv
# Processing ./basic5000/BASIC5000_0128.wav with ./align_result_5000/alignment_0128.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0128.csv
# Processing ./basic5000/BASIC5000_0129.wav with ./align_result_5000/alignment_0129.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0129.csv
# Processing ./basic5000/BASIC5000_0130.wav with ./align_result_5000/alignment_0130.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0130.csv
# Processing ./basic5000/BASIC5000_0131.wav with ./align_result_5000/alignment_0131.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0131.csv
# Processing ./basic5000/BASIC5000_0132.wav with ./align_result_5000/alignment_0132.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0132.csv
# Processing ./basic5000/BASIC5000_0133.wav with ./align_result_5000/alignment_0133.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0133.csv
# Processing ./basic5000/BASIC5000_0134.wav with ./align_result_5000/alignment_0134.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0134.csv
# Processing ./basic5000/BASIC5000_0135.wav with ./align_result_5000/alignment_0135.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0135.csv
# Processing ./basic5000/BASIC5000_0136.wav with ./align_result_5000/alignment_0136.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0136.csv
# Processing ./basic5000/BASIC5000_0137.wav with ./align_result_5000/alignment_0137.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0137.csv
# Processing ./basic5000/BASIC5000_0138.wav with ./align_result_5000/alignment_0138.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0138.csv
# Processing ./basic5000/BASIC5000_0139.wav with ./align_result_5000/alignment_0139.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0139.csv
# Processing ./basic5000/BASIC5000_0140.wav with ./align_result_5000/alignment_0140.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0140.csv
# Processing ./basic5000/BASIC5000_0141.wav with ./align_result_5000/alignment_0141.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0141.csv
# Processing ./basic5000/BASIC5000_0142.wav with ./align_result_5000/alignment_0142.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0142.csv
# Processing ./basic5000/BASIC5000_0143.wav with ./align_result_5000/alignment_0143.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0143.csv
# Processing ./basic5000/BASIC5000_0144.wav with ./align_result_5000/alignment_0144.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0144.csv
# Processing ./basic5000/BASIC5000_0145.wav with ./align_result_5000/alignment_0145.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0145.csv
# Processing ./basic5000/BASIC5000_0146.wav with ./align_result_5000/alignment_0146.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0146.csv
# Processing ./basic5000/BASIC5000_0147.wav with ./align_result_5000/alignment_0147.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0147.csv
# Processing ./basic5000/BASIC5000_0148.wav with ./align_result_5000/alignment_0148.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0148.csv
# Processing ./basic5000/BASIC5000_0149.wav with ./align_result_5000/alignment_0149.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0149.csv
# Processing ./basic5000/BASIC5000_0150.wav with ./align_result_5000/alignment_0150.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0150.csv
# Processing ./basic5000/BASIC5000_0151.wav with ./align_result_5000/alignment_0151.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0151.csv
# Processing ./basic5000/BASIC5000_0152.wav with ./align_result_5000/alignment_0152.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0152.csv
# Processing ./basic5000/BASIC5000_0153.wav with ./align_result_5000/alignment_0153.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0153.csv
# Processing ./basic5000/BASIC5000_0154.wav with ./align_result_5000/alignment_0154.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0154.csv
# Processing ./basic5000/BASIC5000_0155.wav with ./align_result_5000/alignment_0155.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0155.csv
# Processing ./basic5000/BASIC5000_0156.wav with ./align_result_5000/alignment_0156.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0156.csv
# Processing ./basic5000/BASIC5000_0157.wav with ./align_result_5000/alignment_0157.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0157.csv
# Processing ./basic5000/BASIC5000_0158.wav with ./align_result_5000/alignment_0158.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0158.csv
# Processing ./basic5000/BASIC5000_0159.wav with ./align_result_5000/alignment_0159.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0159.csv
# Processing ./basic5000/BASIC5000_0160.wav with ./align_result_5000/alignment_0160.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0160.csv
# Processing ./basic5000/BASIC5000_0161.wav with ./align_result_5000/alignment_0161.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0161.csv
# Processing ./basic5000/BASIC5000_0162.wav with ./align_result_5000/alignment_0162.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0162.csv
# Processing ./basic5000/BASIC5000_0163.wav with ./align_result_5000/alignment_0163.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0163.csv
# Processing ./basic5000/BASIC5000_0164.wav with ./align_result_5000/alignment_0164.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0164.csv
# Processing ./basic5000/BASIC5000_0165.wav with ./align_result_5000/alignment_0165.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0165.csv
# Processing ./basic5000/BASIC5000_0166.wav with ./align_result_5000/alignment_0166.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0166.csv
# Processing ./basic5000/BASIC5000_0167.wav with ./align_result_5000/alignment_0167.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0167.csv
# Processing ./basic5000/BASIC5000_0168.wav with ./align_result_5000/alignment_0168.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0168.csv
# Processing ./basic5000/BASIC5000_0169.wav with ./align_result_5000/alignment_0169.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0169.csv
# Processing ./basic5000/BASIC5000_0170.wav with ./align_result_5000/alignment_0170.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0170.csv
# Processing ./basic5000/BASIC5000_0171.wav with ./align_result_5000/alignment_0171.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0171.csv
# Processing ./basic5000/BASIC5000_0172.wav with ./align_result_5000/alignment_0172.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0172.csv
# Processing ./basic5000/BASIC5000_0173.wav with ./align_result_5000/alignment_0173.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0173.csv
# Processing ./basic5000/BASIC5000_0174.wav with ./align_result_5000/alignment_0174.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0174.csv
# Processing ./basic5000/BASIC5000_0175.wav with ./align_result_5000/alignment_0175.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0175.csv
# Processing ./basic5000/BASIC5000_0176.wav with ./align_result_5000/alignment_0176.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0176.csv
# Processing ./basic5000/BASIC5000_0177.wav with ./align_result_5000/alignment_0177.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0177.csv
# Processing ./basic5000/BASIC5000_0178.wav with ./align_result_5000/alignment_0178.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0178.csv
# Processing ./basic5000/BASIC5000_0179.wav with ./align_result_5000/alignment_0179.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0179.csv
# Processing ./basic5000/BASIC5000_0180.wav with ./align_result_5000/alignment_0180.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0180.csv
# Processing ./basic5000/BASIC5000_0181.wav with ./align_result_5000/alignment_0181.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0181.csv
# Processing ./basic5000/BASIC5000_0182.wav with ./align_result_5000/alignment_0182.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0182.csv
# Processing ./basic5000/BASIC5000_0183.wav with ./align_result_5000/alignment_0183.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0183.csv
# Processing ./basic5000/BASIC5000_0184.wav with ./align_result_5000/alignment_0184.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0184.csv
# Processing ./basic5000/BASIC5000_0185.wav with ./align_result_5000/alignment_0185.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0185.csv
# Processing ./basic5000/BASIC5000_0186.wav with ./align_result_5000/alignment_0186.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0186.csv
# Processing ./basic5000/BASIC5000_0187.wav with ./align_result_5000/alignment_0187.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0187.csv
# Processing ./basic5000/BASIC5000_0188.wav with ./align_result_5000/alignment_0188.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0188.csv
# Processing ./basic5000/BASIC5000_0189.wav with ./align_result_5000/alignment_0189.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0189.csv
# Processing ./basic5000/BASIC5000_0190.wav with ./align_result_5000/alignment_0190.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0190.csv
# Processing ./basic5000/BASIC5000_0191.wav with ./align_result_5000/alignment_0191.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0191.csv
# Processing ./basic5000/BASIC5000_0192.wav with ./align_result_5000/alignment_0192.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0192.csv
# Processing ./basic5000/BASIC5000_0193.wav with ./align_result_5000/alignment_0193.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0193.csv
# Processing ./basic5000/BASIC5000_0194.wav with ./align_result_5000/alignment_0194.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0194.csv
# Processing ./basic5000/BASIC5000_0195.wav with ./align_result_5000/alignment_0195.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0195.csv
# Processing ./basic5000/BASIC5000_0196.wav with ./align_result_5000/alignment_0196.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0196.csv
# Processing ./basic5000/BASIC5000_0197.wav with ./align_result_5000/alignment_0197.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0197.csv
# Processing ./basic5000/BASIC5000_0198.wav with ./align_result_5000/alignment_0198.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0198.csv
# Processing ./basic5000/BASIC5000_0199.wav with ./align_result_5000/alignment_0199.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0199.csv
# Processing ./basic5000/BASIC5000_0200.wav with ./align_result_5000/alignment_0200.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0200.csv
# Processing ./basic5000/BASIC5000_0201.wav with ./align_result_5000/alignment_0201.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0201.csv
# Processing ./basic5000/BASIC5000_0202.wav with ./align_result_5000/alignment_0202.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0202.csv
# Processing ./basic5000/BASIC5000_0203.wav with ./align_result_5000/alignment_0203.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0203.csv
# Processing ./basic5000/BASIC5000_0204.wav with ./align_result_5000/alignment_0204.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0204.csv
# Processing ./basic5000/BASIC5000_0205.wav with ./align_result_5000/alignment_0205.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0205.csv
# Processing ./basic5000/BASIC5000_0206.wav with ./align_result_5000/alignment_0206.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0206.csv
# Processing ./basic5000/BASIC5000_0207.wav with ./align_result_5000/alignment_0207.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0207.csv
# Processing ./basic5000/BASIC5000_0208.wav with ./align_result_5000/alignment_0208.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0208.csv
# Processing ./basic5000/BASIC5000_0209.wav with ./align_result_5000/alignment_0209.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0209.csv
# Processing ./basic5000/BASIC5000_0210.wav with ./align_result_5000/alignment_0210.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0210.csv
# Processing ./basic5000/BASIC5000_0211.wav with ./align_result_5000/alignment_0211.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0211.csv
# Processing ./basic5000/BASIC5000_0212.wav with ./align_result_5000/alignment_0212.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0212.csv
# Processing ./basic5000/BASIC5000_0213.wav with ./align_result_5000/alignment_0213.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0213.csv
# Processing ./basic5000/BASIC5000_0214.wav with ./align_result_5000/alignment_0214.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0214.csv
# Processing ./basic5000/BASIC5000_0215.wav with ./align_result_5000/alignment_0215.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0215.csv
# Processing ./basic5000/BASIC5000_0216.wav with ./align_result_5000/alignment_0216.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0216.csv
# Processing ./basic5000/BASIC5000_0217.wav with ./align_result_5000/alignment_0217.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0217.csv
# Processing ./basic5000/BASIC5000_0218.wav with ./align_result_5000/alignment_0218.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0218.csv
# Processing ./basic5000/BASIC5000_0219.wav with ./align_result_5000/alignment_0219.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0219.csv
# Processing ./basic5000/BASIC5000_0220.wav with ./align_result_5000/alignment_0220.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0220.csv
# Processing ./basic5000/BASIC5000_0221.wav with ./align_result_5000/alignment_0221.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0221.csv
# Processing ./basic5000/BASIC5000_0222.wav with ./align_result_5000/alignment_0222.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0222.csv
# Processing ./basic5000/BASIC5000_0223.wav with ./align_result_5000/alignment_0223.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0223.csv
# Processing ./basic5000/BASIC5000_0224.wav with ./align_result_5000/alignment_0224.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0224.csv
# Processing ./basic5000/BASIC5000_0225.wav with ./align_result_5000/alignment_0225.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0225.csv
# Processing ./basic5000/BASIC5000_0226.wav with ./align_result_5000/alignment_0226.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0226.csv
# Processing ./basic5000/BASIC5000_0227.wav with ./align_result_5000/alignment_0227.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0227.csv
# Processing ./basic5000/BASIC5000_0228.wav with ./align_result_5000/alignment_0228.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0228.csv
# Processing ./basic5000/BASIC5000_0229.wav with ./align_result_5000/alignment_0229.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0229.csv
# Processing ./basic5000/BASIC5000_0230.wav with ./align_result_5000/alignment_0230.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0230.csv
# Processing ./basic5000/BASIC5000_0231.wav with ./align_result_5000/alignment_0231.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0231.csv
# Processing ./basic5000/BASIC5000_0232.wav with ./align_result_5000/alignment_0232.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0232.csv
# Processing ./basic5000/BASIC5000_0233.wav with ./align_result_5000/alignment_0233.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0233.csv
# Processing ./basic5000/BASIC5000_0234.wav with ./align_result_5000/alignment_0234.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0234.csv
# Processing ./basic5000/BASIC5000_0235.wav with ./align_result_5000/alignment_0235.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0235.csv
# Processing ./basic5000/BASIC5000_0236.wav with ./align_result_5000/alignment_0236.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0236.csv
# Processing ./basic5000/BASIC5000_0237.wav with ./align_result_5000/alignment_0237.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0237.csv
# Processing ./basic5000/BASIC5000_0238.wav with ./align_result_5000/alignment_0238.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0238.csv
# Processing ./basic5000/BASIC5000_0239.wav with ./align_result_5000/alignment_0239.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0239.csv
# Processing ./basic5000/BASIC5000_0240.wav with ./align_result_5000/alignment_0240.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0240.csv
# Processing ./basic5000/BASIC5000_0241.wav with ./align_result_5000/alignment_0241.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0241.csv
# Processing ./basic5000/BASIC5000_0242.wav with ./align_result_5000/alignment_0242.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0242.csv
# Processing ./basic5000/BASIC5000_0243.wav with ./align_result_5000/alignment_0243.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0243.csv
# Processing ./basic5000/BASIC5000_0244.wav with ./align_result_5000/alignment_0244.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0244.csv
# Processing ./basic5000/BASIC5000_0245.wav with ./align_result_5000/alignment_0245.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0245.csv
# Processing ./basic5000/BASIC5000_0246.wav with ./align_result_5000/alignment_0246.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0246.csv
# Processing ./basic5000/BASIC5000_0247.wav with ./align_result_5000/alignment_0247.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0247.csv
# Processing ./basic5000/BASIC5000_0248.wav with ./align_result_5000/alignment_0248.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0248.csv
# Processing ./basic5000/BASIC5000_0249.wav with ./align_result_5000/alignment_0249.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0249.csv
# Processing ./basic5000/BASIC5000_0250.wav with ./align_result_5000/alignment_0250.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0250.csv
# Processing ./basic5000/BASIC5000_0251.wav with ./align_result_5000/alignment_0251.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0251.csv
# Processing ./basic5000/BASIC5000_0252.wav with ./align_result_5000/alignment_0252.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0252.csv
# Processing ./basic5000/BASIC5000_0253.wav with ./align_result_5000/alignment_0253.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0253.csv
# Processing ./basic5000/BASIC5000_0254.wav with ./align_result_5000/alignment_0254.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0254.csv
# Processing ./basic5000/BASIC5000_0255.wav with ./align_result_5000/alignment_0255.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0255.csv
# Processing ./basic5000/BASIC5000_0256.wav with ./align_result_5000/alignment_0256.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0256.csv
# Processing ./basic5000/BASIC5000_0257.wav with ./align_result_5000/alignment_0257.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0257.csv
# Processing ./basic5000/BASIC5000_0258.wav with ./align_result_5000/alignment_0258.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0258.csv
# Processing ./basic5000/BASIC5000_0259.wav with ./align_result_5000/alignment_0259.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0259.csv
# Processing ./basic5000/BASIC5000_0260.wav with ./align_result_5000/alignment_0260.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0260.csv
# Processing ./basic5000/BASIC5000_0261.wav with ./align_result_5000/alignment_0261.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0261.csv
# Processing ./basic5000/BASIC5000_0262.wav with ./align_result_5000/alignment_0262.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0262.csv
# Processing ./basic5000/BASIC5000_0263.wav with ./align_result_5000/alignment_0263.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0263.csv
# Processing ./basic5000/BASIC5000_0264.wav with ./align_result_5000/alignment_0264.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0264.csv
# Processing ./basic5000/BASIC5000_0265.wav with ./align_result_5000/alignment_0265.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0265.csv
# Processing ./basic5000/BASIC5000_0266.wav with ./align_result_5000/alignment_0266.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0266.csv
# Processing ./basic5000/BASIC5000_0267.wav with ./align_result_5000/alignment_0267.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0267.csv
# Processing ./basic5000/BASIC5000_0268.wav with ./align_result_5000/alignment_0268.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0268.csv
# Processing ./basic5000/BASIC5000_0269.wav with ./align_result_5000/alignment_0269.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0269.csv
# Processing ./basic5000/BASIC5000_0270.wav with ./align_result_5000/alignment_0270.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0270.csv
# Processing ./basic5000/BASIC5000_0271.wav with ./align_result_5000/alignment_0271.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0271.csv
# Processing ./basic5000/BASIC5000_0272.wav with ./align_result_5000/alignment_0272.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0272.csv
# Processing ./basic5000/BASIC5000_0273.wav with ./align_result_5000/alignment_0273.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0273.csv
# Processing ./basic5000/BASIC5000_0274.wav with ./align_result_5000/alignment_0274.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0274.csv
# Processing ./basic5000/BASIC5000_0275.wav with ./align_result_5000/alignment_0275.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0275.csv
# Processing ./basic5000/BASIC5000_0276.wav with ./align_result_5000/alignment_0276.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0276.csv
# Processing ./basic5000/BASIC5000_0277.wav with ./align_result_5000/alignment_0277.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0277.csv
# Processing ./basic5000/BASIC5000_0278.wav with ./align_result_5000/alignment_0278.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0278.csv
# Processing ./basic5000/BASIC5000_0279.wav with ./align_result_5000/alignment_0279.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0279.csv
# Processing ./basic5000/BASIC5000_0280.wav with ./align_result_5000/alignment_0280.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0280.csv
# Processing ./basic5000/BASIC5000_0281.wav with ./align_result_5000/alignment_0281.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0281.csv
# Processing ./basic5000/BASIC5000_0282.wav with ./align_result_5000/alignment_0282.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0282.csv
# Processing ./basic5000/BASIC5000_0283.wav with ./align_result_5000/alignment_0283.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0283.csv
# Processing ./basic5000/BASIC5000_0284.wav with ./align_result_5000/alignment_0284.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0284.csv
# Processing ./basic5000/BASIC5000_0285.wav with ./align_result_5000/alignment_0285.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0285.csv
# Processing ./basic5000/BASIC5000_0286.wav with ./align_result_5000/alignment_0286.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0286.csv
# Processing ./basic5000/BASIC5000_0287.wav with ./align_result_5000/alignment_0287.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0287.csv
# Processing ./basic5000/BASIC5000_0288.wav with ./align_result_5000/alignment_0288.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0288.csv
# Processing ./basic5000/BASIC5000_0289.wav with ./align_result_5000/alignment_0289.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0289.csv
# Processing ./basic5000/BASIC5000_0290.wav with ./align_result_5000/alignment_0290.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0290.csv
# Processing ./basic5000/BASIC5000_0291.wav with ./align_result_5000/alignment_0291.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0291.csv
# Processing ./basic5000/BASIC5000_0292.wav with ./align_result_5000/alignment_0292.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0292.csv
# Processing ./basic5000/BASIC5000_0293.wav with ./align_result_5000/alignment_0293.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0293.csv
# Processing ./basic5000/BASIC5000_0294.wav with ./align_result_5000/alignment_0294.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0294.csv
# Processing ./basic5000/BASIC5000_0295.wav with ./align_result_5000/alignment_0295.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0295.csv
# Processing ./basic5000/BASIC5000_0296.wav with ./align_result_5000/alignment_0296.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0296.csv
# Processing ./basic5000/BASIC5000_0297.wav with ./align_result_5000/alignment_0297.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0297.csv
# Processing ./basic5000/BASIC5000_0298.wav with ./align_result_5000/alignment_0298.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0298.csv
# Processing ./basic5000/BASIC5000_0299.wav with ./align_result_5000/alignment_0299.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0299.csv
# Processing ./basic5000/BASIC5000_0300.wav with ./align_result_5000/alignment_0300.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0300.csv
# Processing ./basic5000/BASIC5000_0301.wav with ./align_result_5000/alignment_0301.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0301.csv
# Processing ./basic5000/BASIC5000_0302.wav with ./align_result_5000/alignment_0302.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0302.csv
# Processing ./basic5000/BASIC5000_0303.wav with ./align_result_5000/alignment_0303.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_0303.csv
# Processing ./basic5000/BASIC5000_0304.wav with ./align_result_5000/alignment_0304.csv...
# ...
# Processing ./basic5000/BASIC5000_4900.wav with ./align_result_5000/alignment_4900.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4900.csv
# Processing ./basic5000/BASIC5000_4901.wav with ./align_result_5000/alignment_4901.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4901.csv
# Processing ./basic5000/BASIC5000_4902.wav with ./align_result_5000/alignment_4902.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4902.csv
# Processing ./basic5000/BASIC5000_4903.wav with ./align_result_5000/alignment_4903.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4903.csv
# Processing ./basic5000/BASIC5000_4904.wav with ./align_result_5000/alignment_4904.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4904.csv
# Processing ./basic5000/BASIC5000_4905.wav with ./align_result_5000/alignment_4905.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4905.csv
# Processing ./basic5000/BASIC5000_4906.wav with ./align_result_5000/alignment_4906.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4906.csv
# Processing ./basic5000/BASIC5000_4907.wav with ./align_result_5000/alignment_4907.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4907.csv
# Processing ./basic5000/BASIC5000_4908.wav with ./align_result_5000/alignment_4908.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4908.csv
# Processing ./basic5000/BASIC5000_4909.wav with ./align_result_5000/alignment_4909.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4909.csv
# Processing ./basic5000/BASIC5000_4910.wav with ./align_result_5000/alignment_4910.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4910.csv
# Processing ./basic5000/BASIC5000_4911.wav with ./align_result_5000/alignment_4911.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4911.csv
# Processing ./basic5000/BASIC5000_4912.wav with ./align_result_5000/alignment_4912.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4912.csv
# Processing ./basic5000/BASIC5000_4913.wav with ./align_result_5000/alignment_4913.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4913.csv
# Processing ./basic5000/BASIC5000_4914.wav with ./align_result_5000/alignment_4914.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4914.csv
# Processing ./basic5000/BASIC5000_4915.wav with ./align_result_5000/alignment_4915.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4915.csv
# Processing ./basic5000/BASIC5000_4916.wav with ./align_result_5000/alignment_4916.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4916.csv
# Processing ./basic5000/BASIC5000_4917.wav with ./align_result_5000/alignment_4917.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4917.csv
# Processing ./basic5000/BASIC5000_4918.wav with ./align_result_5000/alignment_4918.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4918.csv
# Processing ./basic5000/BASIC5000_4919.wav with ./align_result_5000/alignment_4919.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4919.csv
# Processing ./basic5000/BASIC5000_4920.wav with ./align_result_5000/alignment_4920.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4920.csv
# Processing ./basic5000/BASIC5000_4921.wav with ./align_result_5000/alignment_4921.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4921.csv
# Processing ./basic5000/BASIC5000_4922.wav with ./align_result_5000/alignment_4922.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4922.csv
# Processing ./basic5000/BASIC5000_4923.wav with ./align_result_5000/alignment_4923.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4923.csv
# Processing ./basic5000/BASIC5000_4924.wav with ./align_result_5000/alignment_4924.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4924.csv
# Processing ./basic5000/BASIC5000_4925.wav with ./align_result_5000/alignment_4925.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4925.csv
# Processing ./basic5000/BASIC5000_4926.wav with ./align_result_5000/alignment_4926.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4926.csv
# Processing ./basic5000/BASIC5000_4927.wav with ./align_result_5000/alignment_4927.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4927.csv
# Processing ./basic5000/BASIC5000_4928.wav with ./align_result_5000/alignment_4928.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4928.csv
# Processing ./basic5000/BASIC5000_4929.wav with ./align_result_5000/alignment_4929.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4929.csv
# Processing ./basic5000/BASIC5000_4930.wav with ./align_result_5000/alignment_4930.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4930.csv
# Processing ./basic5000/BASIC5000_4931.wav with ./align_result_5000/alignment_4931.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4931.csv
# Processing ./basic5000/BASIC5000_4932.wav with ./align_result_5000/alignment_4932.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4932.csv
# Processing ./basic5000/BASIC5000_4933.wav with ./align_result_5000/alignment_4933.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4933.csv
# Processing ./basic5000/BASIC5000_4934.wav with ./align_result_5000/alignment_4934.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4934.csv
# Processing ./basic5000/BASIC5000_4935.wav with ./align_result_5000/alignment_4935.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4935.csv
# Processing ./basic5000/BASIC5000_4936.wav with ./align_result_5000/alignment_4936.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4936.csv
# Processing ./basic5000/BASIC5000_4937.wav with ./align_result_5000/alignment_4937.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4937.csv
# Processing ./basic5000/BASIC5000_4938.wav with ./align_result_5000/alignment_4938.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4938.csv
# Processing ./basic5000/BASIC5000_4939.wav with ./align_result_5000/alignment_4939.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4939.csv
# Processing ./basic5000/BASIC5000_4940.wav with ./align_result_5000/alignment_4940.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4940.csv
# Processing ./basic5000/BASIC5000_4941.wav with ./align_result_5000/alignment_4941.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4941.csv
# Processing ./basic5000/BASIC5000_4942.wav with ./align_result_5000/alignment_4942.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4942.csv
# Processing ./basic5000/BASIC5000_4943.wav with ./align_result_5000/alignment_4943.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4943.csv
# Processing ./basic5000/BASIC5000_4944.wav with ./align_result_5000/alignment_4944.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4944.csv
# Processing ./basic5000/BASIC5000_4945.wav with ./align_result_5000/alignment_4945.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4945.csv
# Processing ./basic5000/BASIC5000_4946.wav with ./align_result_5000/alignment_4946.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4946.csv
# Processing ./basic5000/BASIC5000_4947.wav with ./align_result_5000/alignment_4947.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4947.csv
# Processing ./basic5000/BASIC5000_4948.wav with ./align_result_5000/alignment_4948.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4948.csv
# Processing ./basic5000/BASIC5000_4949.wav with ./align_result_5000/alignment_4949.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4949.csv
# Processing ./basic5000/BASIC5000_4950.wav with ./align_result_5000/alignment_4950.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4950.csv
# Processing ./basic5000/BASIC5000_4951.wav with ./align_result_5000/alignment_4951.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4951.csv
# Processing ./basic5000/BASIC5000_4952.wav with ./align_result_5000/alignment_4952.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4952.csv
# Processing ./basic5000/BASIC5000_4953.wav with ./align_result_5000/alignment_4953.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4953.csv
# Processing ./basic5000/BASIC5000_4954.wav with ./align_result_5000/alignment_4954.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4954.csv
# Processing ./basic5000/BASIC5000_4955.wav with ./align_result_5000/alignment_4955.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4955.csv
# Processing ./basic5000/BASIC5000_4956.wav with ./align_result_5000/alignment_4956.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4956.csv
# Processing ./basic5000/BASIC5000_4957.wav with ./align_result_5000/alignment_4957.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4957.csv
# Processing ./basic5000/BASIC5000_4958.wav with ./align_result_5000/alignment_4958.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4958.csv
# Processing ./basic5000/BASIC5000_4959.wav with ./align_result_5000/alignment_4959.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4959.csv
# Processing ./basic5000/BASIC5000_4960.wav with ./align_result_5000/alignment_4960.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4960.csv
# Processing ./basic5000/BASIC5000_4961.wav with ./align_result_5000/alignment_4961.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4961.csv
# Processing ./basic5000/BASIC5000_4962.wav with ./align_result_5000/alignment_4962.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4962.csv
# Processing ./basic5000/BASIC5000_4963.wav with ./align_result_5000/alignment_4963.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4963.csv
# Processing ./basic5000/BASIC5000_4964.wav with ./align_result_5000/alignment_4964.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4964.csv
# Processing ./basic5000/BASIC5000_4965.wav with ./align_result_5000/alignment_4965.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4965.csv
# Processing ./basic5000/BASIC5000_4966.wav with ./align_result_5000/alignment_4966.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4966.csv
# Processing ./basic5000/BASIC5000_4967.wav with ./align_result_5000/alignment_4967.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4967.csv
# Processing ./basic5000/BASIC5000_4968.wav with ./align_result_5000/alignment_4968.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4968.csv
# Processing ./basic5000/BASIC5000_4969.wav with ./align_result_5000/alignment_4969.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4969.csv
# Processing ./basic5000/BASIC5000_4970.wav with ./align_result_5000/alignment_4970.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4970.csv
# Processing ./basic5000/BASIC5000_4971.wav with ./align_result_5000/alignment_4971.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4971.csv
# Processing ./basic5000/BASIC5000_4972.wav with ./align_result_5000/alignment_4972.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4972.csv
# Processing ./basic5000/BASIC5000_4973.wav with ./align_result_5000/alignment_4973.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4973.csv
# Processing ./basic5000/BASIC5000_4974.wav with ./align_result_5000/alignment_4974.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4974.csv
# Processing ./basic5000/BASIC5000_4975.wav with ./align_result_5000/alignment_4975.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4975.csv
# Processing ./basic5000/BASIC5000_4976.wav with ./align_result_5000/alignment_4976.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4976.csv
# Processing ./basic5000/BASIC5000_4977.wav with ./align_result_5000/alignment_4977.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4977.csv
# Processing ./basic5000/BASIC5000_4978.wav with ./align_result_5000/alignment_4978.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4978.csv
# Processing ./basic5000/BASIC5000_4979.wav with ./align_result_5000/alignment_4979.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4979.csv
# Processing ./basic5000/BASIC5000_4980.wav with ./align_result_5000/alignment_4980.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4980.csv
# Processing ./basic5000/BASIC5000_4981.wav with ./align_result_5000/alignment_4981.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4981.csv
# Processing ./basic5000/BASIC5000_4982.wav with ./align_result_5000/alignment_4982.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4982.csv
# Processing ./basic5000/BASIC5000_4983.wav with ./align_result_5000/alignment_4983.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4983.csv
# Processing ./basic5000/BASIC5000_4984.wav with ./align_result_5000/alignment_4984.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4984.csv
# Processing ./basic5000/BASIC5000_4985.wav with ./align_result_5000/alignment_4985.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4985.csv
# Processing ./basic5000/BASIC5000_4986.wav with ./align_result_5000/alignment_4986.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4986.csv
# Processing ./basic5000/BASIC5000_4987.wav with ./align_result_5000/alignment_4987.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4987.csv
# Processing ./basic5000/BASIC5000_4988.wav with ./align_result_5000/alignment_4988.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4988.csv
# Processing ./basic5000/BASIC5000_4989.wav with ./align_result_5000/alignment_4989.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4989.csv
# Processing ./basic5000/BASIC5000_4990.wav with ./align_result_5000/alignment_4990.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4990.csv
# Processing ./basic5000/BASIC5000_4991.wav with ./align_result_5000/alignment_4991.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4991.csv
# Processing ./basic5000/BASIC5000_4992.wav with ./align_result_5000/alignment_4992.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4992.csv
# Processing ./basic5000/BASIC5000_4993.wav with ./align_result_5000/alignment_4993.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4993.csv
# Processing ./basic5000/BASIC5000_4994.wav with ./align_result_5000/alignment_4994.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4994.csv
# Processing ./basic5000/BASIC5000_4995.wav with ./align_result_5000/alignment_4995.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4995.csv
# Processing ./basic5000/BASIC5000_4996.wav with ./align_result_5000/alignment_4996.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4996.csv
# Processing ./basic5000/BASIC5000_4997.wav with ./align_result_5000/alignment_4997.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4997.csv
# Processing ./basic5000/BASIC5000_4998.wav with ./align_result_5000/alignment_4998.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4998.csv
# Processing ./basic5000/BASIC5000_4999.wav with ./align_result_5000/alignment_4999.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_4999.csv
# Processing ./basic5000/BASIC5000_5000.wav with ./align_result_5000/alignment_5000.csv...
# Saved features to ./basic5000_HuBERT_features_csv/alignment_5000.csv

# %%
# ここから！！(学習の特徴量として、HuBERTの特徴量の平均値を使用)
import os
import pandas as pd
from sklearn.model_selection import train_test_split
import torch
from torch.utils.data import Dataset, DataLoader

class AccentDataset(Dataset):
    def __init__(self, csv_files):
        self.data = []
        for file in csv_files:
            df = pd.read_csv(file)
            for _, row in df.iterrows():
                pooled_feature = row['pooled_feature']
                accent = row['Accent']
                self.data.append((pooled_feature, accent))
    
    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        pooled_feature, accent = self.data[idx]
        # 特徴量をベクトルに変換
        pooled_feature = torch.tensor([float(x) for x in pooled_feature.split(',')])  # カンマ区切りで分割
        accent = torch.tensor(accent, dtype=torch.long)
        return pooled_feature, accent

# CSVファイルのパスを取得
csv_folder = 'pooled_features'
csv_files = [os.path.join(csv_folder, f) for f in os.listdir(csv_folder) if f.endswith('.csv')]

# データセットとデータローダの準備
dataset = AccentDataset(csv_files)
train_data, val_data = train_test_split(dataset.data, test_size=0.2, random_state=42)

train_loader = DataLoader(train_data, batch_size=32, shuffle=True)
val_loader = DataLoader(val_data, batch_size=32, shuffle=False)

# %%
import torch.nn as nn

class AccentTransformer(nn.Module):
    def __init__(self, input_dim, num_classes=2, num_heads=4, num_layers=2, hidden_dim=128):
        super(AccentTransformer, self).__init__()
        
        self.input_dim = input_dim
        self.embed_dim = 32  # 埋め込み次元
        self.num_heads = num_heads
        
        # 入力特徴量の次元を埋め込み次元に変換するための線形層
        self.input_projection = nn.Linear(self.input_dim, self.embed_dim)
        
        # Transformer Encoder
        self.encoder = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(d_model=self.embed_dim, nhead=self.num_heads, dim_feedforward=hidden_dim),
            num_layers=num_layers
        )
        
        # 最終層（分類器）
        self.fc = nn.Linear(self.embed_dim, num_classes)
    
    def forward(self, x):
        # x: (batch_size, sequence_length, input_dim)
        
        # 特徴量を埋め込み次元に変換
        x = self.input_projection(x)  # (batch_size, sequence_length, embed_dim)
        
        # Transformerに入力するために次元を変更
        x = x.permute(1, 0, 2)  # (sequence_length, batch_size, embed_dim)
        
        # Transformerに通す
        x = self.encoder(x)
        
        # 出力の平均を取る（シーケンス全体の特徴量を集約）
        x = x.mean(dim=0)  # (batch_size, embed_dim)
        
        # 最終的にアクセント（0 or 1）を予測
        output = self.fc(x)  # (batch_size, num_classes)

        return output

# %%
from tqdm import tqdm
import torch.optim as optim
import torch.nn.functional as F

# モデルと最適化アルゴリズムの設定
model = AccentTransformer(input_dim=32)  # input_dim は特徴量の数（pooled_feature の次元数）
optimizer = optim.Adam(model.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()

# 学習ループ
num_epochs = 100
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

for epoch in range(num_epochs):
    model.train()
    pbar = tqdm(train_loader, desc=f'Epoch {epoch+1}/{num_epochs}', ncols=100)
    for batch in pbar:
        pooled_features, accents = batch
        pooled_features = pooled_features.float().to(device)
        accents = accents.to(device)
        
        # 順伝播
        outputs = model(pooled_features)
        
        # 損失計算
        loss = criterion(outputs, accents)
        
        # 勾配の初期化と逆伝播
        optimizer.zero_grad()
        loss.backward()
        
        # パラメータの更新
        optimizer.step()

        pbar.set_postfix({'loss': loss.item()})
    
    # 評価
    model.eval()
    with torch.no_grad():
        correct = 0
        total = 0
        for batch in val_loader:
            pooled_features, accents = batch
            pooled_features = pooled_features.float().to(device)
            accents = accents.to(device)
            
            outputs = model(pooled_features)
            _, predicted = torch.max(outputs, 1)
            
            total += accents.size(0)
            correct += (predicted == accents).sum().item()

        accuracy = 100 * correct / total
        print(f'Validation Accuracy: {accuracy:.2f}%')
# Out:
# Epoch 1/100:   0%|                                                         | 0/4428 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[17], line 24
#      21 accents = accents.to(device)
#      23 # 順伝播
# ---> 24 outputs = model(pooled_features)
#      26 # 損失計算
#      27 loss = criterion(outputs, accents)
#
# File ~/.conda/envs/sotuken/lib/python3.9/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/.conda/envs/sotuken/lib/python3.9/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# Cell In[14], line 30, in AccentTransformer.forward(self, x)
#      27 x = self.input_projection(x)  # (batch_size, sequence_length, embed_dim)
#      29 # Transformerに入力するために次元を変更
# ---> 30 x = x.permute(1, 0, 2)  # (sequence_length, batch_size, embed_dim)
#      32 # Transformerに通す
#      33 x = self.encoder(x)
#
# RuntimeError: permute(sparse_coo): number of dimensions in the tensor input does not match the length of the desired ordering of dimensions i.e. input.dim() = 1 is not equal to len(dims) = 3

# %%
class AccentTransformer(nn.Module):
    def __init__(self, input_dim, num_classes=2, num_heads=4, num_layers=2, hidden_dim=128):
        super(AccentTransformer, self).__init__()

        # 埋め込み次元（入力次元）を num_heads で割り切れる値に変更
        self.embed_dim = 32  # 例: 32 は num_heads=4 で割り切れます
        self.input_dim = input_dim  # 特徴量の次元数を保持
        
        # 入力の次元を埋め込み次元に変換するための線形層
        self.input_projection = nn.Linear(self.input_dim, self.embed_dim)
        
        # Transformer Encoder
        self.encoder = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(d_model=self.embed_dim, nhead=num_heads, dim_feedforward=hidden_dim),
            num_layers=num_layers
        )
        
        # 最終層
        self.fc = nn.Linear(self.embed_dim, num_classes)
    
    def forward(self, x):
        # x: (batch_size, sequence_length, feature_dim)
        
        # 特徴量の次元を embed_dim に変換
        x = self.input_projection(x)  # (batch_size, sequence_length, embed_dim)
        
        # Transformerに入力するために次元を変更
        x = x.permute(1, 0, 2)  # (sequence_length, batch_size, embed_dim) に変換
        
        # Transformerに通す
        x = self.encoder(x)
        
        # 出力の平均を取る（シーケンス全体の特徴量を集約）
        x = x.mean(dim=0)  # (batch_size, embed_dim)
        
        # fc 層に入力するために次元を変換
        output = self.fc(x)  # (batch_size, num_classes)

        return output

# %%
# モデル、損失関数、最適化器の設定
input_dim = 1  # pooled_featureは1次元なので
model = AccentTransformer(input_dim=input_dim)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# 学習ループ
num_epochs = 100
for epoch in range(num_epochs):
    model.train()
    total_loss = 0

    # 学習データでのトレーニング
    with tqdm(train_loader, desc=f"Epoch {epoch+1}/{num_epochs}", unit="batch") as pbar:
        for features, labels in pbar:
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
            
            pbar.set_postfix(loss=loss.item())
    
    print(f"Epoch {epoch+1}, Loss: {total_loss / len(train_loader)}")

    # 評価データでの評価
    model.eval()
    total_correct = 0
    with torch.no_grad():
        for features, labels in eval_loader:
            outputs = model(features)
            _, predicted = torch.max(outputs, 1)
            total_correct += (predicted == labels).sum().item()

    accuracy = total_correct / len(eval_loader.dataset)
    print(f"Epoch {epoch+1}, Accuracy: {accuracy:.4f}")
# Out:
# Epoch 1/100:   0%|          | 0/4428 [00:00<?, ?batch/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[11], line 18
#      16 for features, labels in pbar:
#      17     optimizer.zero_grad()
# ---> 18     outputs = model(features)
#      19     loss = criterion(outputs, labels)
#      20     loss.backward()
#
# File ~/.conda/envs/sotuken/lib/python3.9/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/.conda/envs/sotuken/lib/python3.9/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# Cell In[10], line 25, in AccentTransformer.forward(self, x)
#      21 def forward(self, x):
#      22     # x: (batch_size, sequence_length, feature_dim)
#      23
#      24     # 特徴量の次元を embed_dim に変換
# ---> 25     x = self.input_projection(x)  # (batch_size, sequence_length, embed_dim)
#      27     # Transformerに入力するために次元を変更
#      28     x = x.permute(1, 0, 2)  # (sequence_length, batch_size, embed_dim) に変換
#
# File ~/.conda/envs/sotuken/lib/python3.9/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/.conda/envs/sotuken/lib/python3.9/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/.conda/envs/sotuken/lib/python3.9/site-packages/torch/nn/modules/linear.py:117, in Linear.forward(self, input)
#     116 def forward(self, input: Tensor) -> Tensor:
# --> 117     return F.linear(input, self.weight, self.bias)
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (1x32 and 1x32)
